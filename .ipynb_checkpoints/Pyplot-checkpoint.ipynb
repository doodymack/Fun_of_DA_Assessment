# %% [markdown]
# Author: Paul Mc Grath - HDip in Data Analytics- GMIT 2021-2022 Semester Assignment

# %% [markdown]
# <img src="images/logo2.svg" width="300"/>

# %% [markdown]
# # Overview of matplotlib.pyplot python package <br><br>  <img src="images/logo2.svg" width="200"/>
#
# Python offers a variety of packages for plotting data.<br>
# Matplotlib is a library for data visualization, typically in the form of plots, graphs and charts.<br>
# **Pyplot** is an API (Application Programming Interface) for Python’s **matplotlib**. <br>
# Python effectively makes matplotlib a viable open source alternative to *MATLAB*. <br>
# This Notebook is a guide to matplotlib pyplot and related libraries.<br><br>
# ##### History:
# Matplotlib is a multi-platform data visualization library built on NumPy arrays. <br>It was conceived by John Hunter in 2002, originally as a patch to IPython for enabling interactive MATLAB-style plotting. Version 0.1 released in 2003. <br>It received an early boost when it was adopted as the plotting package of choice of the Space Telescope Science Institute (the folks behind the Hubble Telescope), which financially supported Matplotlib’s development and greatly expanded its capabilities.
#
# ##### Sourcing
# - matplotlib.pyplot is accessible via python if not already on your machine recommend to download python via downloading [Anaconda](https://www.anaconda.com/products/individual)
# - To access the functionality of matplotlib.pyplot the following libraries should be downloaded:<br>
# - Most of the Matplotlib utilities lies under the pyplot submodule and are usually imported under the plt alias: "matplotlib.pyplot as plt"
#
# ##### *import numpy as np*
# ##### *import matplotlib.pyplot as plt* <br>
# - '%matplotlib inline' is run so that the plot will show underneath the code chunk automatically when it is executed. Otherwise the user will need to type plt.show() everytime a new plot is created.
# -Note: *plt.rcParams.update()* changes the default parameters in matplotlib applying the properties to all the plots created in the notebook.

# %%
# import required libraries
import matplotlib.pyplot as plt

# %matplotlib inline

import numpy as np

import seaborn as sns

# %% [markdown]
# ### Beginning with matplotlib

# %% [markdown]
# IMPORTANT PYPLOT COMMANDS:
# plt.figure() – Set the properties of the figure canvas <br>
# plt.subplot() – Select the subplot to draw within the figure<br>
# plt.plot() – Makes a line plot by default but can make other types. <br>
# plt.subplots() – Create and initialize the figure and axes.<br>
# plt.scatter(x,y) – Draw a scatterplot of x and y.<br>
# plt.pie() – Create a pie chart.<br>
# plt.hist() – Create a histogram.<br>
# plt.hist2d() – Create 2-D Histogram.<br>
# plt.bar() – Create bar plot.<br>
# modifying the plpt:<br>
# plt.text() – Add text annotation inside the plot.<br>
# plt.colorbar() – Add a colorbar: Color of dots in scatterplot is set based on a continuous numeric variable.<br>
# plt.xlabel(), plt.ylabel() – label the x and y axis.<br>
# plt.xlim(), plt.ylim() – Set X and Y axis limits.<br>
# plt.title() – Add current plot’s title.<br>
# plt.legend() – Set the legend for current plot.<br>
# plt.suptitle() – Apply a title for entire figure.<br>
# plt.tight_layout() – Tightly arrange the subplots.<br>
# plt.xticks(), plt.yticks() – Adjust the x and y axis ticks position and labels.<br>
# plt.show() – Display the entire plot

# %%
#simple x,y plot
xpoints = np.array([0, 6])
ypoints = np.array([0, 250])

plt.plot(xpoints, ypoints)

# %% [markdown]
# Parameter 1 is an array containing the points on the x-axis. <br>
# Parameter 2 is an array containing the points on the y-axis.<br>
# If we need to plot a line from (1, 80) to (3, 100), we have to pass two arrays [1, 80] and [3, 100] to the plot function.

# %%
#simple x,y plot
# remove the matplotlib default image reference by adding ';'
# change the scales of x y
xpoints = np.array([1, 800])
ypoints = np.array([3, 1000])

plt.plot(xpoints, ypoints);

# %%
#simple x,y plot
# if just want to plot points only
plt.plot(xpoints, ypoints, 'o');

# %%
# plot multiple points
xpoints = np.arange(1, 10, 2.5)
ypoints = np.array([3, 6, 1, 5])

plt.plot(xpoints, ypoints);

# %% [markdown]
# If we do not specify the points in the x-axis, they will get the default values 0, 1, 2, 3,

# %%
#simple x,y plot- of an array
ypoints = np.array([3, 6, 3, 18])

plt.plot(ypoints);

# %%
#simple x,y plot- of an array with points
ypoints = np.array([3, 6, 3, 18])
plt.plot(ypoints, marker = 'o');

# %%
#simple x,y plot- change the points shape
ypoints = np.array([3, 6, 3, 18])
plt.plot(ypoints, marker = '*');

# %% [markdown]
# 'o' = Circle;
# '*' = Star;
# '.' = Point;
# ',' = Pixel;
# 'x' = X;
# 'X' = X (filled);
# '+' = Plus;
# 'P' = Plus (filled);
# 's' = Square;
# 'D' = Diamond <br>
# 'd' = Diamond (thin);
# 'p' = Pentagon;
# 'H' = Hexagon;
# 'h' = Hexagon;
# 'v' = Triangle Down;
# '^' = Triangle Up;
# '<' = Triangle Left;
# '>' = Triangle Right;
# '1' = Tri Down;
# '2' = Tri Up <br>
# '3' = Tri Left;
# '4' = Tri Right;
# '|' = Vline;
# '_' = Hline

# %%
# plot functions i.e. multiple exponential plots
x = np.linspace(0,5,50) # 50 values between 0 and 5.
y1 = np.exp(x)
y2 = np.exp(x-1)
y3 = np.exp(x+1)

plt.plot(x,y1, '-',color='blue')
plt.plot(x,y2,'--',color='red')
plt.plot(x,y3, '-c',color='green');
plt.xlabel('X Axis')
plt.ylabel('Exponetial value')
# Out:
# Text(0, 0.5, 'Exponetial value')

# %%
#simple x,y plot- change the points colour
ypoints = np.array([3, 6, 3, 18])

plt.plot(ypoints, 'o:r')
plt.show()

# %% [markdown]
# Color Syntax	Description
# 'r'	Red
# 'g'	Green
# 'b'	Blue
# 'c'	Cyan
# 'm'	Magenta
# 'y'	Yellow
# 'k'	Black
# 'w'	White

# %%
#simple x,y plot- change the points shape,size and colour
# marker size = ms
# markerfacecolour = mfc
# marker edge colour = mec
ypoints = np.array([3, 6, 1, 10])
plt.plot(ypoints, marker ='o', ms =30, mec ='r', mfc= 'g');

# %% [markdown]
# [marker colours](https://www.w3schools.com/colors/colors_names.asp)

# %%
# simple x,y plot- change the line type
ypoints = np.arange(1, 10, 2.5)
plt.plot(ypoints, linestyle = 'dotted');

# %%
#simple x,y plot- change the line type and colour
#linestyle =ls
#dotted = :
#dashed = "dashed" or ""--""
# none = "
#colour = as per points
ypoints = np.arange(1, 10, 2.5)
plt.plot(ypoints, ls = '--', c= 'r');

# %%
#simple x,y plot- change the linewidth = lw
ypoints = np.arange(1, 100, 10)
plt.plot(ypoints, ls= 'dotted', lw ='20');

# %%
#simple x,y plot- two plots on on axes
y1 = np.arange(1, 10, 2.5)
y2 = np.array([6, 2, 7, 11])

plt.plot(y1)
plt.plot(y2, ls = '--', c= 'r');

# %% [markdown]
# ### Labels
# #### use the xlabel() and ylabel() functions to set a label for the x- and y-axis.

# %%
# plot x vs 2 x y arrays
# adding x & y labels
# adding titles
# adding gridlines
x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.arange(1, 10, 2.5)
y2 = np.array([6, 2, 7, 11])


font1 = {'family':'serif','color':'blue','size':15}
font2 = {'family':'serif','color':'darkred','size':15}
# loc = left , right  or center
plt.plot(x1, y1, x2, y2)

# loc = left , right  or center

#plot the title
plt.title("Mfg line 1", loc = 'right')

#plot the x label. Use'fontdict= attributes contained in dict object as above
plt.xlabel("rpm", loc ='left', fontdict = font1)

#plot the y label.Use 'fontdict= attributes contained in dict object as above
plt.ylabel("Quantity", loc = 'top', fontdict = font2)

#plot a grid
#plt.grid()
#plt.grid(axis ='x')
plt.grid(axis ='y', color = 'green', linestyle = ':', linewidth = 2)

# %% [markdown]
# ### Sub-plots
# #### How to display more than one plot in one output

# %%
# plotting side to side plots (horizontal)
#plot 1:
x = np.arange(1, 10, 2.5)
y = np.array([3, 8, 1, 10])

#SYNTAX: plt.subplot(ROWS, COLUMNS, SUBLPLOT #)
#define the location of the subplot 1
#the figure has 1 row, 2 columns, and this plot is the first plot
plt.subplot(1, 2, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

#define the location of the subplot 2
#the figure has 1 row, 2 columns, and this plot is the second plot.
plt.subplot(1, 2, 2)
plt.plot(x,y);

# %%
# plotting side to side plots (top & bottom)

#plot 1:
x = np.arange(1, 10, 2.5)
y = np.array([3, 8, 1, 10])

#define the location of the subplot 1
#the figure has 2 row, 1 columns, and this plot is the first plot
plt.subplot(2, 1, 1)
plt.plot(x,y)

#define the location of the subplot 2
#the figure has 2 row, 1 columns, and this plot is the 2nd plot
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 1, 2)
plt.plot(x,y);

# %%
# multiple plots (i.e. 6 in 2 rows)
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

#the figure has 2 row, 3 columns, i.e. 2 x 3 or 6 subplots & this is the first plot
plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([10, 20, 30, 40, 50])
y = np.array([10, 20, 30, 40, 50])

plt.subplot(2, 3, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.arange(1, 10, 2.5)
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.arange(1, 100, 25)
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y);

# %% [markdown]
# ### Scatter
# #### How to generate a scatter plot from matplotlib

# %%
# create a scatter plot of two arrays
x = np.arange(1, 27, 2)
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y);

# %%
# create a scatter plot of ONE arrays-add labels & legends
font1 = {'family':'serif','color':'blue','size':15}
font2 = {'family':'serif','color':'darkred','size':15}

#plot the title
plt.title("Car watching", loc = 'center')

#plot the x label. Use'fontdict= attributes contained in dict object as above
plt.xlabel("Car age", loc ='center', fontdict = font1)

#plot the y label.Use 'fontdict= attributes contained in dict object as above
plt.ylabel("Car speed", loc = 'center', fontdict = font2)

x = np.arange(1, 27, 2)
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y);

# %%
# create a scatter plot of TWO arrays-add labels & legends
# colour code the scatter points for diffrentiation

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}


#plot the title
plt.title("Car watching", loc = 'center')

#plot the x label. Use'fontdict= attributes contained in dict object as above
plt.xlabel("Car age", loc ='center', fontdict = font1)

#plot the y label.Use 'fontdict= attributes contained in dict object as above
plt.ylabel("Car speed", loc = 'center', fontdict = font2)

#day one observations:
x = np.arange(1, 27, 2)
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, color = 'hotpink')

#day two observations:
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y, color = '#88c999');

# plt.scatter (x,y) twice otherwise only one scatter plot printed

# %%
# colours cme font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

#plot the title
plt.title("Car watching", loc = 'center')

#plot the x label. Use'fontdict= attributes contained in dict object as above
plt.xlabel("Car age", loc ='center', fontdict = font1)

#plot the y label.Use 'fontdict= attributes contained in dict object as above
plt.ylabel("Car speed", loc = 'center', fontdict = font2)

#observations:
x = np.arange(1, 27, 2)
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
#individually colour the points based on a new array- quantity of array numbers/colors has to match
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])

plt.scatter(x, y, c=colors);

# %% [markdown]
# ### Adding another dimension via cvolour scale
# #### Create a color array, and specify a colormap in the scatter plot: <br>
# e.g. viridis color array
#
# ![image.png](attachment:8456c2b4-261c-4747-b834-38d7e36e0deb.png)

# %% [markdown]
# ##### use the colur array to dictate dot colour- add the colour array to the side

# %%
#plot the title
plt.title("Car watching", loc = 'center')

#plot the x label. Use'fontdict= attributes contained in dict object as above
plt.xlabel("Car age")
#plot the y label.Use 'fontdict= attributes contained in dict object as above
plt.ylabel("Car speed")

#observations:
x = np.arange(1, 27, 2)
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')

#include the colormap to the side of the plot

plt.colorbar();

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='RdBu_r')

plt.colorbar();

# %% [markdown]
# ---
# <br>
#
# ## 2. Three interesting plots from the matplotlib.pyplot python package

# %% [markdown]
# #### 2a. Exploring the relationship between three variables: number of bike rentals at different temperature and seasons by use of **Scatter Plots**

# %% [markdown]
# - A scatter plot is one of the most influential, informative, and versatile plots in matplotlib
# - It can convey a significant amount of information to the viewer.
# - *plt.scatter()* will give us a scatter plot of the data we pass in as the initial arguments.
# - temp is the x-axis and cnt is the y-axis.
# - c determines the colors of the data points.
# - In the below plots - 'season' which is a column of the dataframe 'day', the colours correspond to the different seasons.
# - This is a quick and easy method to group data in a visual format.
# - Note: If you want to understand how two variables change with respect to each other, the function *sns.lmplot()* line of best fit can be used.

# %%
import pandas as pd

# %%
df = pd.read_csv('data/day.csv')

# %% [markdown]
# ---
# <br>
#
# ![image.png](attachment:a59cf038-9704-432d-a430-43505dedcae3.png) <br>
# reproduced from https://www.kdnuggets.com/2019/04/data-visualization-python-matplotlib-seaborn.html

# %% [markdown]
# Each colour corresponds to the different seasons (purple =spring, blue =summer, green = autumn, yellow =winter). <br> From the correlation plot:
# 1. There were more than 8000 bike rentals at some point in time.<br>
# 2. The amount of bike rentals does not differ much with season (blue and yellow).<br>
# 3. However within a season temperature does influence bike rental. <br>Note this could be temporal i.e time of day. <br>Further analysis versus this attribute would be needed to prove or discount the hypothesis<br>
# 3. Most importantly there is overall a positive linear relationship between bike rentals and normalized temperature.<br>
# <br><br>

# %% [markdown]
# ---
# <br>While combined scatter plots are good for visualisations, subplots allow individual correlations be discerned.<br>
# Faceting is thev act of creating individual subplots. <br> Subplots are necessary when a single plot is overcrowded andthe information cannot be assessed in that state. <br>
# This allows trends that were obscured by other plots be revealed.

# %% [markdown]
# ![image.png](attachment:ba0efb41-7062-40d5-92cf-c24148d13283.png) <br>
# reproduced from https://www.kdnuggets.com/2019/04/data-visualization-python-matplotlib-seaborn.html

# %% [markdown]
#  Newly discernable from the subplots is: <br>
#  - the relationship between bike rental and temperature (normalized) differs between seasons. <br>
#  - there is a positive linear correlation between bike rentals and normalized temperature in Spring
#  - there is a potentially weak linear correlation between bike rentals and normalized temperature for Summer and Winter
#  - there is no discernable relationship/correlation between bike rentals and normalized temperature for Autumn.

# %% [markdown]
# ---
# <br>However upon closer inspection of the individual X and Y axes these differ between sub-plot.<br>
# One option would be to plot the 4 sub-plots stacked on top of each other but with the same Y scale: <br>

# %% [markdown]
# ![image.png](attachment:f2a04ff1-aaf0-413d-9e31-14b3cd37c962.png)

# %% [markdown]
# The plotgrid has now been adjusted so that the Y axes scales align.<br>
# In this view additional information is discernable:
# - On average the lowest temperatures occur in Spring
# - On average the highset temperatures occur in Autumn
# - The top figure reinfoces there is a clear correlation between bike rentals and temperature in spring.
# - Once again caution is required here as the correlation may be confounded with time i.e. the time of day is not identified in the dataframe above. <br>The assumption is the temperature is daily average temperature or the temperature was measured at the same time each day.

# %% [markdown]
# Comment: The code in https://www.kdnuggets.com/2019/04/data-visualization-python-matplotlib-seaborn.html includes: 'ax2.scatter('temp', 'cnt', data=day.loc[day['season']==2], c="orange)'. <br>   May be more appropriate to use 'atemp' for correlation assuming 'atemp' relates to 'average temp'.

# %% [markdown]
# An effective chart is one which:
#
# - Conveys the right and necessary information without distorting facts.
# - Simple in design, you don’t have to strain in order to get it.
# - Aesthetics support the information rather than overshadow it.
# - Not overloaded with information.

# %% [markdown]
# ---
# <br>
#
# ### 2b. Exploring the Fisher Iris Dataset using Histograms

# %% [markdown]
# ##### Irisdataset:
#
# <img src="images/iris-machinelearning.png" width="400"/>
#
# The Iris Dataset contains four features (length and width of sepals and petals) of 50 samples of three species of Iris (Iris setosa, Iris virginica and Iris versicolor). <br> The dataset is often used in data mining, classification and clustering examples and to test algorithms.

# %% [markdown]
# ##### Histogram:
# A histogram is a graph showing frequency distributions. It is a graph showing the number of observations within each given interval. <br>To demonstrate the basic functionality of matplotlib.histogram the standard iris dataset is used below. <br>Simple code can be written to plot attributes of the iris dataset, while separating for each species. <br> Matplotlib allows for plotting multiple histograms on the one plot. <br> This can be useful when establishing if parameters czan be used to distinguish subsets suchas iris species.

# %%
df2 = pd.read_csv("https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv")

# %%
df2
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# Multiple Histograms
# Data
df3 = df2[df2['species']=='setosa']
df4 = df2[df2['species']=='virginica']
df5 = df2[df2['species']=='versicolor']

#Change the size of the plot
plt.rcParams.update({'figure.figsize':(7.5,5), 'figure.dpi':100})

# Plot the histogram for all 3 parts in the same graph
plt.hist(df3['sepal_length'], bins=10, label ='setosa')
plt.hist(df4['sepal_length'], bins=10, label = 'versicolor')
plt.hist(df5['sepal_length'], bins=10, label = 'virginica')
plt.xlabel('sepal_length')
#plt.ylabel('Distribution')
#plt.show()
plt.legend()

# %%
# Multiple Histograms
# Data
df3 = df2[df2['species']=='setosa']
df4 = df2[df2['species']=='virginica']
df5 = df2[df2['species']=='versicolor']

#Change the size of the plot
plt.rcParams.update({'figure.figsize':(7.5,5), 'figure.dpi':100})

# Plot the histogram for all 3 parts in the same graph
plt.hist(df3['sepal_width'], bins=10, label ='setosa')
plt.hist(df4['sepal_width'], bins=10, label = 'versicolor')
plt.hist(df5['sepal_width'], bins=10, label = 'virginica')
plt.xlabel('petal_width')
#plt.ylabel('Distribution')
#plt.show()
plt.legend()

# %%
# Multiple Histograms
# Data
df3 = df2[df2['species']=='setosa']
df4 = df2[df2['species']=='virginica']
df5 = df2[df2['species']=='versicolor']

#Change the size of the plot
plt.rcParams.update({'figure.figsize':(7.5,5), 'figure.dpi':100})

# Plot the histogram for all 3 parts in the same graph
plt.hist(df3['petal_length'], bins=10, label ='setosa')
plt.hist(df4['petal_length'], bins=10, label = 'versicolor')
plt.hist(df5['petal_length'], bins=10, label = 'virginica')
plt.xlabel('petal_length')
#plt.ylabel('Distribution')
#plt.show()
plt.legend()

# %%
# Multiple Histograms
# Data
df3 = df2[df2['species']=='setosa']
df4 = df2[df2['species']=='virginica']
df5 = df2[df2['species']=='versicolor']

#Change the size of the plot
plt.rcParams.update({'figure.figsize':(7.5,5), 'figure.dpi':100})

# Plot the histogram for all 3 parts in the same graph
plt.hist(df3['petal_width'], bins=10, label ='setosa')
plt.hist(df4['petal_width'], bins=10, label = 'versicolor')
plt.hist(df5['petal_width'], bins=10, label = 'virginica')
plt.xlabel('petal_width')
#plt.ylabel('Distribution')
#plt.show()
plt.legend()

# %% [markdown]
# Thus from use of simple matplotlib tools and basic code the following can be established for the iris data:
#
# - The higest values of petal length and petal width are observed for iris versicolor
# - With the exception of petal width the lowest parameter values for occur for iris setosa
# - There is significant overlap of sepal length and petal width for all three species
# - Iris setosa petal length and petal width values do not overlap with the other species for the same parameters.
# - Thus an algorihtm can be created to classify iris setosa from a mixture of the.
# - However there is less overlap for values for petal width.
# - Thus this parameter could still be useful in classifying albeit tentatively.

# %% [markdown]
# ### 2c Use of a pairwise plot for a deeper dive into the Iris Dataset
#
# Seaborn is a Python data visualization library based on matplotlib. <br> It provides a high-level interface for drawing attractive and informative statistical graphics.

# %% [markdown]
# ---
# <br>
#
# ### Pairwise plot

# %% [markdown]
# - Pairwise plot is a favorite in exploratory analysis to understand the relationship between all possible pairs of numeric variables.
# - It is a much more visually appealing way of publishing an array of scatter plots and histograms in one plot.
# - Pairwise is available under the seaborn library.

# %%
df2 = pd.read_csv("https://raw.githubusercontent.com/uiuc-cse/data-fa14/gh-pages/data/iris.csv")

# %%
# Plot the pairwise plot, kind ='scatter'
plt.figure(figsize=(10,8), dpi= 80)
sns.pairplot(df2, kind="scatter", hue="species", plot_kws=dict(s=80, edgecolor="white", linewidth=2.5))

# %% [markdown]
# The pairplot allows a complete visual assessment of correlations between attributes i.e the four features of length and width of sepals and length and width of petals. <br>
# Correlations between these 4 attributes are plotted in a grid format<br>
# The pairplot function creates a grid of Axes such that each variable in data will by shared in the y-axis across a single row and in the x-axis across a single column.<br>
# The hue function can be used to visualize the correlations with another dimension i.e. species. <br>

# %% [markdown]
# If the realtionship between just two attributes are required a simpler pairplot can be used:

# %% [markdown]
# <br>
#
# ---

# %%
plot2x2 = sns.pairplot(df2, vars=["petal_width", "petal_length"],hue="species")

# %% [markdown]
# The pairplot also allows the plotting of the combined kernel density estimate <br>
# In this case species is not identified i.e. 'hue' is not defined. <br>
# This allows plotting of the overall kde for the dataset.

# %% [markdown]
# <br>
#
# ---

# %%
plot_kde = sns.pairplot(df2, diag_kind="kde")

# %% [markdown]
# <br>
#
# ---
#
# #### Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python.
# #### The above introduction and three examples give a basic understanding of the usefulness of matplotlib.pyplot and associated libraries for data plotting.
# #### Matplotlib works seamlessly with many backend platforms.
# #### Matplotlib is a very useful tool available to the data analyst in processing, visualization and analysis of complex datasets.
# #### Matplotlib and associated libraries provide many more tools than shown here.  For more information refer to the references.

# %% [markdown]
# <br>
#
# ---
# ### References
#
# 1. https://www.kdnuggets.com/2019/04/data-visualization-python-matplotlib-seaborn.html
# 2. https://matplotlib.org/stable/users/index.html
# 3. https://www.w3schools.com/python/matplotlib_intro.asp
# 4. https://www.kdnuggets.com/2019/04/data-visualization-python-matplotlib-seaborn.html
# 5.https://realpython.com/python-matplotlib-guide/
# 7. https://towardsdatascience.com/all-your-matplotlib-questions-answered-420dd95cb4ff
# 8. https://www.machinelearningplus.com/plots/matplotlib-tutorial-complete-guide-python-plot-examples/
# 9. https://www.machinelearningplus.com/plots/top-50-matplotlib-visualizations-the-master-plots-python/
# 10.https://www.datacamp.com/community/blog/python-matplotlib-cheat-sheet
# 11. https://www.python-graph-gallery.com/matplotlib/
# 12.https://s3.amazonaws.com/assets.datacamp.com/blog_assets/Python_Matplotlib_Cheat_Sheet.pdf
# 13. https://towardsdatascience.com/matplotlib-cheat-sheet-f441c43971c4
# 14. https://matplotlib.org/3.1.0/gallery/index.html
# 15. https://matplotlib.org/stable/users/index.html
# 16.https://realpython.com/python-matplotlib-guide/
# 17.https://www.activestate.com/resources/quick-reads/what-is-pyplot-in-matplotlib/
# 18. https://towardsdatascience.com/all-your-matplotlib-questions-answered-420dd95cb4ff
# 19. https://www.machinelearningplus.com/plots/matplotlib-tutorial-complete-guide-python-plot-examples/
# 20. https://www.machinelearningplus.com/plots/top-50-matplotlib-visualizations-the-master-plots-python/
# 21.https://www.datacamp.com/community/blog/python-matplotlib-cheat-sheet
# 22. https://www.python-graph-gallery.com/matplotlib/
# 23.https://s3.amazonaws.com/assets.datacamp.com/blog_assets/Python_Matplotlib_Cheat_Sheet.pdf
# 24. https://towardsdatascience.com/matplotlib-cheat-sheet-f441c43971c4
# 25. https://matplotlib.org/3.1.0/gallery/index.html
# 26. https://stackoverflow.com/questions/42128467/matplotlib-plot-multiple-columns-of-pandas-data-frame-on-the-bar-chart

# %% [markdown]
# <br>
#
# ---
# ### Citing Matplotlib
# @Article{Hunter:2007,
#   Author    = {Hunter, J. D.},
#   Title     = {Matplotlib: A 2D graphics environment},
#   Journal   = {Computing in Science \& Engineering},
#   Volume    = {9},
#   Number    = {3},
#   Pages     = {90--95},
#   abstract  = {Matplotlib is a 2D graphics package used for Python for
#   application development, interactive scripting, and publication-quality
#   image generation across user interfaces and operating systems.},
#   publisher = {IEEE COMPUTER SOC},
#   doi       = {10.1109/MCSE.2007.55},
#   year      = 2007
# } <br><br>
#
# Note: '%matplotlib inline' is run so that the plot will show underneath the code chunk automatically when it is executed. Otherwise the user will need to type plt.show() everytime a new plot is created.
